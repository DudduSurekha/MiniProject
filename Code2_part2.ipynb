# %%
model = YOLO("yolov8n.pt")  # Try "yolov8s.pt" or "yolov8l.pt" for more accuracy

# %%
import cv2
import matplotlib.pyplot as plt

# Load an image
image_path = "/content/place.jpg"  # Ensure this path is correct
results = model(image_path)  # Run YOLOv8 detection

# Convert results to an annotated image
annotated_image = results[0].plot()

# Convert BGR to RGB for correct color display
annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

# Display using Matplotlib (Works in Colab)
plt.imshow(annotated_image)
plt.axis("off")  # Hide axes
plt.show()
# Out:
# image 1/1 /content/place.jpg: 448x640 4 persons, 1 horse, 219.0ms
# Speed: 5.0ms preprocess, 219.0ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
